# %% [markdown]
# # Colab Smoke Test for `warp_optimization`
#
# This notebook clones the repository from GitHub, installs the Python dependencies, runs a reduced end-to-end smoke test, and verifies the generated outputs.
#
# For a private repository, provide a GitHub token in the first code cell before cloning.
#
# Update the token field in the first code cell before running if you are cloning the private repository.

# %%
REPO_URL = "https://github.com/xys004/warp_bubble_optimization.git"
REPO_DIR = "warp_optimization"
GITHUB_TOKEN = ""  # Required for private-repo clone in Colab.

clone_url = REPO_URL if not GITHUB_TOKEN else REPO_URL.replace("https://", f"https://{GITHUB_TOKEN}@")

# !rm -rf "$REPO_DIR"
# !git clone "$clone_url" "$REPO_DIR"
# %cd $REPO_DIR
# %pip install -r requirements.txt

# %%
# !python generate_run_bundle.py --domain 2 --v 0.1 --t 30.0 --epochs 10 --n-xyz 12 --pretrain-trials 0

# %%
# !python verify_outputs.py --base domain_2_v_0p1_t_30p0

# %% [markdown]
# ## Optional higher-fidelity rerun
#
# After the smoke test passes, you can rerun the helper with larger settings, for example by increasing `--epochs`, `--n-xyz`, and pretraining options.
